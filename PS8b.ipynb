# %%
"""
quick Select
function quickSelect(list, left, right, k)
{
sizeA = len(A)
Math = math.floor(sizeA/4)

 
    // If k is smaller than number of  
    // elements in array 
    if (k > 0 && k <= r - l + 1) { 
  
        // Partition the array around last  
        // element and get position of pivot  
        // element in sorted array 
        int index = partition(arr, l, r); 
  
        // If position is same as k 
        if (index - l == k - 1) 
            return index; #change this so that instead of retruning the array value arr[index] you return the index
  
        // If position is more, recur  
        // for left subarray 
        if (index - l > k - 1)  
            return kthSmallest(arr, l, index - 1, k); 
  
        // Else recur for right subarray 
        return kthSmallest(arr, index + 1, r,  
                            k - index + l - 1); 
    } 
  
    // If k is more than number of  
    // elements in array 
    return INT_MAX; 
} 
 """   
"""
quickSort(A,p,r)
//A is array or subarray to sort
//P is the left index of A
//r is the right index of A
sizeA = len(A)
Math = math.floor(sizeA/4)-1

if (p<r)
    w =quickSelect(A,P,r,Math) 
    #q = partition(A, p, r)  // does partition take in what quickSelect returns in this case and should QuickSel return an index or a value, index makes more sense
    quickSort(A,p,w-r) // left of the pivot
    quickSort(A,w+1,r) // right of the pivot
"""

"""
Partition(A,p,r)

// A[p....r] is array to partition
//p>=0 . r < last index in A
// After Partition all elements A[p...q-1]<= A[q]<A[q+1...r] Doesnt say that A is sorted at end of Partition 



x=A[r] // this is the pivot . Last element in array. Design choose. 
i=p-1
for j=p to r-1
    count+=1
    ifA[q] <=x
    i=i+1
    swap(A[j],A[i])
swap(A[i+1],A[r])
return i+1
"""
